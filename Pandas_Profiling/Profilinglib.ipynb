# %%
from pandas_profiling import ProfileReport
import pandas as pd

df = pd.read_csv('/Users/apple/VS code /ML/EDA/train.csv')

# %%
prof = ProfileReport(df)
prof.to_file(output_file='output.html')
# Out:
# ...
# Export report to file: 100%|██████████| 1/1 [00:00<00:00, 125.61it/s]
