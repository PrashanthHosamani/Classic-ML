# %% [markdown]
# 1. Data Collection
#
# When the data gathering is quite difficult, In that case we should prefer fetch the data from the API and we scrapping
#
# 2. Insufficient Data / Labelled Data
#
# Algo A & Algo B, depending on the data any one of the algorithm would be good enough to compare
#
# 3. Non Representative data
#
# 4. Poor Quality data
#
# 5. Irrelevent Features
#
# 6. Over fitting
#
# 7. Under fitting
#
# 8. Software Integration
#
# 9. Offline Learning / Deployment
#
# 10. Cost Involved
