# %%
import pandas as pd

# %%
pd.read_json('train.json')
# Out:
#           id      cuisine                                        ingredients
# 0      10259        greek  [romaine lettuce, black olives, grape tomatoes...
# 1      25693  southern_us  [plain flour, ground pepper, salt, tomatoes, g...
# 2      20130     filipino  [eggs, pepper, salt, mayonaise, cooking oil, g...
# 3      22213       indian                [water, vegetable oil, wheat, salt]
# 4      13162       indian  [black pepper, shallots, cornflour, cayenne pe...
# ...      ...          ...                                                ...
# 39769  29109        irish  [light brown sugar, granulated sugar, butter, ...
# 39770  11462      italian  [KRAFT Zesty Italian Dressing, purple onion, b...
# 39771   2238        irish  [eggs, citrus fruit, raisins, sourdough starte...
# 39772  41882      chinese  [boneless chicken skinless thigh, minced garli...
# 39773   2362      mexican  [green chile, jalapeno chilies, onions, ground...
#
# [39774 rows x 3 columns]

# %% [markdown]
# Refer Json pandas documentation

# %%
#SQL

import mysql.connector

# %%
connector = mysql.connector.connect(host = 'localhost', user = 'root', password = '', database = 'world' )

# %%
df1 = pd.read_sql_query("SELECT * FROM Country WHERE LifeExpectancy > '70'", connector)
df1
# Out:
# /var/folders/4n/yjd10x_9499596_l5q76lh600000gn/T/ipykernel_35503/73040917.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df1 = pd.read_sql_query("SELECT * FROM Country WHERE LifeExpectancy > '70'", connector)
#     Code                              Name      Continent           Region  \
# 0    ABW                             Aruba  North America        Caribbean
# 1    AIA                          Anguilla  North America        Caribbean
# 2    ALB                           Albania         Europe  Southern Europe
# 3    AND                           Andorra         Europe  Southern Europe
# 4    ANT              Netherlands Antilles  North America        Caribbean
# ..   ...                               ...            ...              ...
# 106  VCT  Saint Vincent and the Grenadines  North America        Caribbean
# ...
