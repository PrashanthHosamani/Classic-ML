# %%
import pandas as pd

# %%
#constructing the dataframe from dictionary

d = {
    'first' : ['prashanth', 'p', 'm', 'a'],
    'last' : ['Hosamnai', 'h', 'n', 'n'],
    'ph' : [+916362000011, 0000, 1111, 0000],
    'email' : ['prashanth@gmail.com', 'p@gmail.com', 'm@gmail.com', 'a@gmail.com']
    
}

df = pd.DataFrame(d)
df
# Out:
#        first      last            ph                email
# 0  prashanth  Hosamnai  916362000011  prashanth@gmail.com
# 1          p         h             0          p@gmail.com
# 2          m         n          1111          m@gmail.com
# 3          a         n             0          a@gmail.com

# %%
#accessing any column
df['email']
# Out:
# 0    prashanth@gmail.com
# 1            p@gmail.com
# 2            m@gmail.com
# 3            a@gmail.com
# Name: email, dtype: object

# %%
#series : rows of only one column (data frame is a container for the object of the series)
type(df['email'])
# Out:
# pandas.core.series.Series

# %%
#access multiple columns
df[['ph', 'email']]
# Out:
#              ph                email
# 0  916362000011  prashanth@gmail.com
# 1             0          p@gmail.com
# 2          1111          m@gmail.com
# 3             0          a@gmail.com

# %%
df.columns
# Out:
# Index(['first', 'last', 'ph', 'email'], dtype='object')

# %%
df
# Out:
#        first      last            ph                email
# 0  prashanth  Hosamnai  916362000011  prashanth@gmail.com
# 1          p         h             0          p@gmail.com
# 2          m         n          1111          m@gmail.com
# 3          a         n             0          a@gmail.com

# %%
df['email']
# Out:
# 0    prashanth@gmail.com
# 1            p@gmail.com
# 2            m@gmail.com
# 3            a@gmail.com
# Name: email, dtype: object

# %%
df.set_index('first', inplace = True)

# %%
df #set the name as an index permanently using inplace = True
# Out:
#                last            ph                email
# first
# prashanth  Hosamnai  916362000011  prashanth@gmail.com
# p                 h             0          p@gmail.com
# m                 n          1111          m@gmail.com
# a                 n             0          a@gmail.com

# %%
df.index
# Out:
# Index(['prashanth', 'p', 'm', 'a'], dtype='object', name='first')

# %%
df.loc['prashanth', 'email']
# Out:
# 'prashanth@gmail.com'

# %%
df.iloc[0]
# Out:
# last                Hosamnai
# ph              916362000011
# email    prashanth@gmail.com
# Name: prashanth, dtype: object

# %%
#to get back everything normal
df.reset_index(inplace= True)

# %%
filt = (df['last'] == 'n')

# %%
#df[df['last'] == 'n']

# %%
df[filt]
# Out:
#   first last    ph        email
# 2     m    n  1111  m@gmail.com
# 3     a    n     0  a@gmail.com

# %%
df.loc[filt]
# Out:
#   first last    ph        email
# 2     m    n  1111  m@gmail.com
# 3     a    n     0  a@gmail.com

# %%
df.loc[filt, 'email']
# Out:
# 2    m@gmail.com
# 3    a@gmail.com
# Name: email, dtype: object

# %%
#& |  for and and or

# %%
filt = (df['last'] == 'n') & (df['first'] == 'm')

# %%
df.loc[filt, 'email']
# Out:
# 2    m@gmail.com
# Name: email, dtype: object

# %% [markdown]
# Update rows and columns

# %%
df.columns
# Out:
# Index(['first', 'last', 'ph', 'email'], dtype='object')

# %%
df.columns = ['first_name', 'last_name', 'ph', 'email']

# %%
df.columns = [x.lower() for x in df.columns]
df
# Out:
#   first_name last_name            ph                email
# 0  prashanth  Hosamnai  916362000011  prashanth@gmail.com
# 1          p         h             0          p@gmail.com
# 2          m         n          1111          m@gmail.com
# 3          a         n             0          a@gmail.com

# %%
df.columns = df.columns.str.replace('_', ' ')
df
# Out:
#   first name last name            ph                email
# 0  prashanth  Hosamnai  916362000011  prashanth@gmail.com
# 1          p         h             0          p@gmail.com
# 2          m         n          1111          m@gmail.com
# 3          a         n             0          a@gmail.com

# %%
df.rename(columns={'first name' : 'first', 'last name' : 'last'}, inplace=True)

# %%
df
# Out:
#        first      last            ph                email
# 0  prashanth  Hosamnai  916362000011  prashanth@gmail.com
# 1          p         h             0          p@gmail.com
# 2          m         n          1111          m@gmail.com
# 3          a         n             0          a@gmail.com

# %%
df.loc[3] = ['john', 'smith', 00000, 'johnsmit@email.com']
df
# Out:
#        first      last            ph                email
# 0  prashanth  Hosamnai  916362000011  prashanth@gmail.com
# 1          p         h             0          p@gmail.com
# 2          m         n          1111          m@gmail.com
# 3       john     smith             0   johnsmit@email.com

# %%
df.loc[2, ['first', 'email']]
# Out:
# first              m
# email    m@gmail.com
# Name: 2, dtype: object

# %%
def update_email(email):
    return email.upper()

# %%
df['email'].apply(update_email)
# Out:
# 0    PRASHANTH@GMAIL.COM
# 1            P@GMAIL.COM
# 2            M@GMAIL.COM
# 3     JOHNSMIT@EMAIL.COM
# Name: email, dtype: object

# %%
df
# Out:
#        first      last            ph                email
# 0  prashanth  Hosamnai  916362000011  prashanth@gmail.com
# 1          p         h             0          p@gmail.com
# 2          m         n          1111          m@gmail.com
# 3       john     smith             0   johnsmit@email.com

# %%
df['email'] = df['email'].apply(update_email)
df
# Out:
#        first      last            ph                email
# 0  prashanth  Hosamnai  916362000011  PRASHANTH@GMAIL.COM
# 1          p         h             0          P@GMAIL.COM
# 2          m         n          1111          M@GMAIL.COM
# 3       john     smith             0   JOHNSMIT@EMAIL.COM

# %%
df['email'] = df['email'].apply(lambda x: x.lower())
df
# Out:
#        first      last            ph                email
# 0  prashanth  Hosamnai  916362000011  prashanth@gmail.com
# 1          p         h             0          p@gmail.com
# 2          m         n          1111          m@gmail.com
# 3       john     smith             0   johnsmit@email.com

# %%
df.apply(len) #what is the length of the columns, this is how apply work with dataframe
# Out:
# first    4
# last     4
# ph       4
# email    4
# dtype: int64

# %%
df.apply(len, axis='columns') #applying it horizontolly that is to columns
# Out:
# 0    4
# 1    4
# 2    4
# 3    4
# dtype: int64

# %%
df['first'] = df['first'].replace({'prashanth' : 'pr', 'john' : 'joy'})
df
# Out:
#   first      last            ph                email
# 0    pr  Hosamnai  916362000011  prashanth@gmail.com
# 1     p         h             0          p@gmail.com
# 2     m         n          1111          m@gmail.com
# 3   joy     smith             0   johnsmit@email.com

# %% [markdown]
# How to combine the columns

# %%
df['first'] + ' ' + df['last']
# Out:
# 0    pr Hosamnai
# 1            p h
# 2            m n
# 3      joy smith
# dtype: object

# %%
df['full_name'] = df['first'] + ' ' + df['last']
df
# Out:
#   first      last            ph                email    full_name
# 0    pr  Hosamnai  916362000011  prashanth@gmail.com  pr Hosamnai
# 1     p         h             0          p@gmail.com          p h
# 2     m         n          1111          m@gmail.com          m n
# 3   joy     smith             0   johnsmit@email.com    joy smith

# %%
#now delete the first and last column
df.drop(columns=['first', 'last'], inplace=True)

# %%
df
# Out:
#              ph                email    full_name
# 0  916362000011  prashanth@gmail.com  pr Hosamnai
# 1             0          p@gmail.com          p h
# 2          1111          m@gmail.com          m n
# 3             0   johnsmit@email.com    joy smith

# %%
df['full_name'].str.split(' ', expand=True)
# Out:
#      0         1
# 0   pr  Hosamnai
# 1    p         h
# 2    m         n
# 3  joy     smith

# %%
df[['first', 'last']] = df['full_name'].str.split(' ', expand=True)
df
# Out:
#              ph                email    full_name first      last
# 0  916362000011  prashanth@gmail.com  pr Hosamnai    pr  Hosamnai
# 1             0          p@gmail.com          p h     p         h
# 2          1111          m@gmail.com          m n     m         n
# 3             0   johnsmit@email.com    joy smith   joy     smith

# %%
df.sort_values(by='first', ascending=False)
# Out:
#              ph                email    full_name first      last
# 0  916362000011  prashanth@gmail.com  pr Hosamnai    pr  Hosamnai
# 1             0          p@gmail.com          p h     p         h
# 2          1111          m@gmail.com          m n     m         n
# 3             0   johnsmit@email.com    joy smith   joy     smith

# %%
df.sort_values(by=['first', 'last'], ascending=False, inplace=True)
df
# Out:
#              ph                email    full_name first      last
# 0  916362000011  prashanth@gmail.com  pr Hosamnai    pr  Hosamnai
# 1             0          p@gmail.com          p h     p         h
# 2          1111          m@gmail.com          m n     m         n
# 3             0   johnsmit@email.com    joy smith   joy     smith
